# %% [markdown]
# # Conditions

# %% [markdown]
# ## 1 Boolean Expressions

# %%
5==5
# Out:
# True

# %%
5==6
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ### 2 != condition

# %%
x=5
y=7
x!=y
# Out:
# True

# %% [markdown]
# ### 3 >= conditions

# %%
x=5
y=7
x>=y
# Out:
# False

# %% [markdown]
# ### 4 <= conditions

# %%
x=5
y=7
x<=y
# Out:
# True

# %% [markdown]
# ### 5 is conditions

# %%
x=5
y=5
x is y
# Out:
# True

# %%
x=5
y=x
x is y
# Out:
# True

# %% [markdown]
# ### 6 is not condition

# %%
x=5
y=x
x is not y
# Out:
# False

# %% [markdown]
# # Logical Operators

# %% [markdown]
# ### 7 and operator

# %%
x=5
x>0 and x<10
# Out:
# True

# %% [markdown]
# ### 8 find mix and min number

# %%
a=3453
b=5
c=56

if a>b and a>c:
    print(f'a is max number : {a}')
elif b>a and b>c:
    print(f'b is max number : {b}')
else :
    print(f'c is max number : {c}')
# Out:
# a is max number : 3453
